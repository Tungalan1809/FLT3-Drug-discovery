# %% [markdown]
# # **Predictive Modeling of FLT3 Bioactivity Using Machine Learning [Part 1] Download Bioactivity Data**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2.4 million compounds. It is compiled from more than 89,900 documents, 1.6 million assays and the data spans 15,000 targets and 2,000 cells and 48,800 indications.
# [Data as of November 14, 2024; ChEMBL version 34].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that bioactivity data can be retrieved from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.8 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.3 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.7 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for FLT3**

# %%
# Target search for FLT3
target = new_client.target
target_query = target.search('FLT3')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0                                                 []  Mus musculus
# 1  [{'xref_id': 'P36888', 'xref_name': None, 'xre...  Homo sapiens
# 2                                                 []  Homo sapiens
# 3                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0         Receptor-type tyrosine-protein kinase FLT3   18.0
# 1              Tyrosine-protein kinase receptor FLT3   16.0
# 2                                           VHL/FLT3   16.0
# 3  Protein cereblon/Tyrosine-protein kinase recep...   16.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL2034796
# 1               False       CHEMBL1974
# 2               False    CHEMBL4523735
# 3               False    CHEMBL4630730
#
#                                    target_components  \
# 0  [{'accession': 'Q00342', 'component_descriptio...
# 1  [{'accession': 'P36888', 'component_descriptio...
# 2  [{'accession': 'P36888', 'component_descriptio...
# 3  [{'accession': 'P36888', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN   10090
# 1               SINGLE PROTEIN    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Receptor-type tyrosine-protein kinase FLT3* (first entry)**

# %% [markdown]
#  Assigned the first entry (which corresponds to the target protein, *Receptor-type tyrosine-protein kinase FLT3*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2034796'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Receptor-type tyrosine-protein kinase FLT3* (CHEMBL2034796) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     10905866                  []
# 1        None             None     10905904                  []
# 2        None             None     10905951                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 1   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 2   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                            target_pref_name target_tax_id  \
# 0    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 1    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 2    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
#
#   text_value  toid  type units    uo_units upper_value value
# 0       None  None  IC50    uM  UO_0000065        None   5.1
# 1       None  None  IC50    uM  UO_0000065        None   2.1
# 2       None  None  IC50    uM  UO_0000065        None   5.5
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# # Saved the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## Copying files to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Handling missing data**

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     10905866                  []
# 1        None             None     10905904                  []
# 2        None             None     10905951                  []
# 3        None             None     10906029                  []
# 4        None             None     10906062                  []
# 5        None             None     10906970                  []
# 6        None             None     14545494                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 1   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 2   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 3   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 4   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 5   CHEMBL2038873  Inhibition of Tel-fused FLT3 in mouse BA/F3 cells
# 6   CHEMBL3225224  Inhibition of FLT3 autophosphorylation in mous...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
# 5          B                    None                   None  BAO_0000190  ...
# 6          B                    None                   None  BAO_0000190  ...
#
#   target_organism                            target_pref_name target_tax_id  \
# 0    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 1    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 2    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 3    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 4    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 5    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
# 6    Mus musculus  Receptor-type tyrosine-protein kinase FLT3         10090
#
#   text_value  toid  type units    uo_units upper_value value
# 0       None  None  IC50    uM  UO_0000065        None   5.1
# 1       None  None  IC50    uM  UO_0000065        None   2.1
# 2       None  None  IC50    uM  UO_0000065        None   5.5
# 3       None  None  IC50    uM  UO_0000065        None   6.4
# 4       None  None  IC50    uM  UO_0000065        None   4.7
# 5       None  None  IC50    uM  UO_0000065        None   9.4
# 6       None  None  IC50    nM  UO_0000065        None   1.5
#
# [7 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  #else:
  #  bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2037226  Cc1ccc(NC(=O)Nc2cc(C(F)(F)F)ccc2F)cc1Nc1ccc2c(...
# 1      CHEMBL2037224  O=C(Nc1cccc(Nc2ccc3c(c2)NC(=O)/C3=C\c2ccc[nH]2...
# 2      CHEMBL2037220  CN1CCN(c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 3      CHEMBL2037211  CN1CCN(c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 4      CHEMBL2037209  Cc1cn(-c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 5      CHEMBL2037208  O=C1Nc2cc(Nc3cccc(NC(=O)c4cccc(C(F)(F)F)c4)c3)...
# 6       CHEMBL603469  C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6...
#
#   standard_value
# 0         5100.0
# 1         2100.0
# 2         5500.0
# 3         6400.0
# 4         4700.0
# 5         9400.0
# 6            1.5

# %%
bioactivity_class = pd.Series(bioactivity_class, name='bioactivity_class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL2037226  Cc1ccc(NC(=O)Nc2cc(C(F)(F)F)ccc2F)cc1Nc1ccc2c(...
# 1      CHEMBL2037224  O=C(Nc1cccc(Nc2ccc3c(c2)NC(=O)/C3=C\c2ccc[nH]2...
# 2      CHEMBL2037220  CN1CCN(c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 3      CHEMBL2037211  CN1CCN(c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 4      CHEMBL2037209  Cc1cn(-c2cc(C(=O)Nc3cccc(Nc4ccc5c(c4)NC(=O)/C5...
# 5      CHEMBL2037208  O=C1Nc2cc(Nc3cccc(NC(=O)c4cccc(C(F)(F)F)c4)c3)...
# 6       CHEMBL603469  C[C@]12O[C@H](C[C@]1(O)CO)n1c3ccccc3c3c4c(c5c6...
#
#   standard_value bioactivity_class
# 0         5100.0            active
# 1         2100.0               NaN
# 2         5500.0               NaN
# 3         6400.0               NaN
# 4         4700.0               NaN
# 5         9400.0               NaN
# 6            1.5               NaN

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_data_preprocessed.csv', index=False)

# %%
! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root  755 Nov 14 11:57 bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root 4347 Nov 14 10:44 bioactivity_data_raw.csv
# drwx------ 7 root root 4096 Nov 14 10:55 gdrive
# drwxr-xr-x 1 root root 4096 Nov 12 14:25 sample_data

# %% [markdown]
# ---
